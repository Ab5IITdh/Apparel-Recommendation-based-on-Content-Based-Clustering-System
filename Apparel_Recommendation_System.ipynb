# %% [markdown]
# # Amazon Apparel Recommendation System

# %% [markdown]
# # 1. Retrieve and Inspect Dataset

# %% [markdown]
# We have a json file which consists of all information about the products, we'll be loading the data using pandas `read_json`.

# %%
import pandas as pd

data = pd.read_json('C:\\Users\\Abhishek Sharma\\Apparel Reccomadation System\\sample_for_amazon_30k_data.ldjson', lines =True)

# %% [markdown]
# Let's see how many rows and columns our dataset has?

# %%
print('Number of data points : ', data.shape[0])
print() 
print('Number of features/variables:', data.shape[1])
# Out:
# Number of data points :  30000
#
# Number of features/variables: 33

# %% [markdown]
# What are the features/column names present?

# %%
data.columns # prints column-names or feature-names.
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'asin', 'product_url', 'product_name',
#        'image_urls__small', 'medium', 'large', 'browsenode', 'brand',
#        'sales_price', 'weight', 'rating', 'sales_rank_in_parent_category',
#        'sales_rank_in_child_category', 'delivery_type', 'meta_keywords',
#        'amazon_prime__y_or_n', 'parent___child_category__all',
#        'best_seller_tag__y_or_n', 'other_items_customers_buy',
#        'product_details__k_v_pairs', 'discount_percentage', 'colour',
#        'no__of_reviews', 'seller_name', 'seller_id', 'left_in_stock',
#        'no__of_offers', 'no__of_sellers', 'technical_details__k_v_pairs',
#        'formats___editions', 'name_of_author_for_books'],
#       dtype='object')

# %% [markdown]
# Here is your content in **Markdown format** with **detailed descriptions and numbering**:
#
# ---
# #
#
# # **Dataset Columns Description**
#
# This dataset contains multiple attributes related to e-commerce products. Below is a detailed description of each column: #
#
# ### **1. Unique Identifier**
# - **`uniq_id`**: A unique identifier assigned to each product in the datase#t.
#
# ### **2. Crawl Information**
# - **`crawl_timestamp`**: The timestamp when the product details were last scraped from the so#urce.
#
# ### **3. Product Identification**
# - **`asin`**: The **Amazon Standard Identification Number (ASIN)**, which is a unique identifier assigned to products by Amazon.
# - **`product_url`**: The direct URL link to the product page on the e-commerce platform.
# - **`product_name`**: The full name or title of the product as listed on th#e website.
#
# ### **4. Product Images**
# - **`image_urls__small`**: URL of the product's **small-sized image**.
# - **`medium`**: URL of the product's **medium-sized image**.
# - **`large`**: URL of the product's **large#-sized image**.
#
# ### **5. Category Information**
# - **`browsenode`**: A classification code representing the product category within the marketplace.
# - **`parent___child_category__all`**: Indicates the **hierarchy of categories** the product belongs to, including parent an#d child categories.
#
# ### **6. Brand Information**
# - **`brand`**: The bran#d name of the product.
#
# ### **7. Pricing and Discounts**
# - **`sales_price`**: The current **selling price** of the product.
# - **`discount_percentage`**: The **discount applied** to #the product, if available.
#
# ### **8. Product Specifications**
# - **`weight`**: The weight of the product (could be in grams, kg, pounds, etc.).
# - **`colour`**: The color variations available for the product.
# - **`technical_details__k_v_pairs`**: Key-value pairs containing **technical s#pecifications** of the product.
#
# ### **9. Sales Performance & Popularity**
# - **`rating`**: The overall **customer rating** (out of 5).
# - **`sales_rank_in_parent_category`**: The **sales rank** of the product within its **parent category**.
# - **`sales_rank_in_child_category`**: The **sales rank** of the product within its **child category**.
# - **`no__of_reviews`**: The total **number of customer reviews** for the product.
# - **`best_seller_tag__y_or_n`**: Indicates whether the product# has a **"Best Seller" tag** (Yes/No).
#
# ### **10. Delivery & Availability**
# - **`delivery_type`**: The shipping or delivery method available for the product (e.g., **standard, express, same-day delivery**).
# - **`amazon_prime__y_or_n`**: Indicates whether the product is eligible for **Amazon Prime shipping** (Yes/No).
# - **`left_in_stock`#**: The number of items remaining in stock.
#
# ### **11. Seller & Marketplace Information**
# - **`seller_name`**: The name of the seller offering the product.
# - **`seller_id`**: A unique identifier for the seller.
# - **`no__of_offers`**: The total number of offers available for this product.
# - **`no__of_sellers#`**: The number of sellers offering this product.
#
# ### **12. Customer Behavior & Recommendations**
# - **`other_items_customers_buy`**: List of **other products frequently bought** by customers who purchased this item.
# - **`meta_keywords`**: Keywords or tags #associated with the product to improve searchability.
#
# ### **13. Additional Information**
# - **`product_details__k_v_pairs`**: Detailed **product attributes** stored as key-value pairs.
# - **`formats___editions`**: Applicable for books or media products, indicating available **formats or editions** (e.g., hardcover, paperback, Kindle edition).
# - **`name_oiew of the dataset. Let me know if you need further modifications! 🚀iew of the dataset. Let me know if you need further modifications! 🚀

# %%
data = data[['asin', 'brand', 'colour', 'image_urls__small', 'product_name', 'rating', 'sales_price', 'product_details__k_v_pairs']]

# %% [markdown]
# Now, let's have a glimpse at our dataframe.

# %%
print('Number of data points : ', data.shape[0])
print()
print('Number of features:', data.shape[1])
print() 
data.head() # prints the top rows in the table.
# Out:
# Number of data points :  30000
#
# Number of features: 8
#          asin      brand colour  \
# 0  B07STS2W9T  LA' Facon    NaN
# 1  B07N6TD2WL        NaN    NaN
# 2  B07WJ6WPN1    LOVISTA    NaN
# 3  B07PYSF4WZ        NaN    NaN
# 4  B082KXNM7X        NaN    NaN
#
#                                    image_urls__small  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
# 3  https://images-na.ssl-images-amazon.com/images...
# 4  https://images-na.ssl-images-amazon.com/images...
#
#                                         product_name  rating  sales_price  \
# 0  LA' Facon Cotton Kalamkari Handblock Saree Blo...     5.0        200.0
# 1  Sf Jeans By Pantaloons Men's Plain Slim fit T-...     3.6        265.0
# 2  LOVISTA Cotton Gota Patti Tassel Traditional P...     3.5        660.0
# 3           People Men's Printed Regular fit T-Shirt     3.0        195.0
# 4  Monte Carlo Grey Solid Cotton Blend Polo Colla...     5.0       1914.0
#
#                           product_details__k_v_pairs
# 0  {'Item_part_number': 'Devi face', 'ASIN': 'B07...
# 1  {'ASIN': 'B07N6TD2WL', 'Date_first_available_a...
# 2  {'Item_part_number': 'KUM-011', 'ASIN': 'B07WJ...
# 3  {'ASIN': 'B07PYSF4WZ', 'Date_first_available_a...
# 4  {'Item_part_number': 'BBAPLMC154483', 'ASIN': ...

# %% [markdown]
# # 2. Basic Statistics Exploration about the Dataset

# %% [markdown]
# ### 2.1 product_name

# %%
  print(data['product_details__k_v_pairs'].describe())
# Out:
# count                                                 28817
# unique                                                28772
# top       {'Item_part_number': 'HB0046ORANGE', 'ASIN': '...
# freq                                                      2
# Name: product_details__k_v_pairs, dtype: object

# %%
  print(data['product_name'].describe())
# Out:
# count                           30000
# unique                          22424
# top       BIBA Women's Straight Kurta
# freq                               70
# Name: product_name, dtype: object

# %% [markdown]
# - We have total 72 unique type of product_type_names
# - 91.62% ( 167794/183138 ) of the products are shirts.

# %%
# names of different product types
print(data['product_name'].unique())
# Out:
# ["LA' Facon Cotton Kalamkari Handblock Saree Blouse Fabric 100 cms Black Base Dancers (Cotton)"
#  "Sf Jeans By Pantaloons Men's Plain Slim fit T-Shirt"
#  'LOVISTA Cotton Gota Patti Tassel Traditional Printed Kurti with Pant,Angrakha Salwar Suit'
#  ... "Indian Virasat Women's Rayon Anarkali Kurta"
#  "PINKY PARI Women's Embroidered Short Denim Straight fit Kurti"
#  "Gutsy Men's Full Sleeve All Over Printed Navy T-Shirt"]

# %%
from collections import Counter

# find the 10 most frequent product_type_names.
product_type_count = Counter(list(data['product_name']))
product_type_count.most_common(10)
# Out:
# [("BIBA Women's Straight Kurta", 70),
#  ('W for Woman Straight Kurta', 63),
#  ("W for Woman Women's Straight Kurta", 55),
#  ("W for Women's Straight Kurta", 47),
#  ("Aurelia Women's Straight Kurta", 43),
#  ("Max Boy's Regular fit T-Shirt", 42),
#  ("Soch Women's Straight Kurta", 41),
#  ("Excalibur by Unlimited Men's Solid Regular Fit Formal Shirt (Pack of 2)(Colors & Print May Vary)",
#   40),
#  ("Max Boy's Regular Fit T-Shirt", 39),
#  ("Aurelia Women's Straight Fit Kurta", 39)]

# %% [markdown]
# ### 2.2 brand

# %%
print(data['brand'].describe())
# Out:
# count     21857
# unique     6458
# top         Max
# freq        504
# Name: brand, dtype: object

# %% [markdown]
# - There are 10577 unique brands
# - ( 183138 - 182987 ) 151 missing values.

# %%
# find the 10 most frequent brand.
brand_count = Counter(list(data['brand']))
brand_count.most_common(10)
# Out:
# [(nan, 8143),
#  ('Max', 504),
#  ('Generic', 245),
#  ('BIBA', 205),
#  ('Mothercare', 156),
#  ('Campus Sutra', 150),
#  ('Soch', 149),
#  ('nauti nati', 132),
#  ('Ada', 127),
#  ('GRITSTONES', 110)]

# %% [markdown]
# ### 2.3 colour

# %%
print(data['colour'].describe())
# Out:
# count            6029
# unique           4757
# top       Black|White
# freq               79
# Name: colour, dtype: object

# %% [markdown]
# - we have 7380 unique colors
# - 7.2% of products are black in color
# - 64956 of 183138 products have color information. That's approx 35.4%.

# %%
# find the 10 most frequent color.
color_count = Counter(list(data['colour']))
color_count.most_common(10)
# Out:
# [(nan, 23971),
#  ('Black|White', 79),
#  ('Black|Blue', 45),
#  ('Black|Red', 34),
#  ('Black|Navy', 31),
#  ('Blue|Red', 30),
#  ('Black|Navy Blue', 21),
#  ('Blue|Pink', 21),
#  ('Black|Grey', 21),
#  ('White|Black', 20)]

# %% [markdown]
# ### 2.4 sales_price

# %%
print(data['sales_price'].describe())
# Out:
# count    27110.000000
# mean       862.172397
# std        964.223008
# min         39.000000
# 25%        379.000000
# 50%        590.000000
# 75%        899.000000
# max       9988.000000
# Name: sales_price, dtype: float64

# %% [markdown]
# Only 28,395 (15.5% of whole data) products with price information

# %%
price_count = Counter(list(data['sales_price']))
price_count.most_common(10)
# Out:
# [(399.0, 1041),
#  (299.0, 912),
#  (599.0, 893),
#  (499.0, 615),
#  (349.0, 601),
#  (799.0, 573),
#  (699.0, 504),
#  (999.0, 481),
#  (899.0, 445),
#  (449.0, 426)]

# %% [markdown]
# - Only 15.5% of whole products with price information, others are 'None'

# %% [markdown]
# ### 2.5 product_name

# %%
print(data['product_name'].describe())
# Out:
# count                           30000
# unique                          22424
# top       BIBA Women's Straight Kurta
# freq                               70
# Name: product_name, dtype: object

# %% [markdown]
# - All of the products have a title.
# - Titles are fairly descriptive of what the product is.
# - We will use titles extensively in this project as they are short and informative.
# - By watching the 'count', we can say that 'title' feature is available for most items. This makes it most important feature too.

# %% [markdown]
# Do we have null values to deal with?

# %%
data.isnull().sum()
# Out:
# asin                     0
# brand                 8143
# colour               23971
# image_urls__small        2
# product_name             0
# rating                   0
# sales_price           2890
# dtype: int64

# %% [markdown]
# Let's serialize the object to a pickle file.

# %%
# data.to_pickle('/content/180k_apparel_data')

# %% [markdown]
# # 3. Dropping Null/Void Values

# %% [markdown]
# In this notebook, we'll be dropping the null values of `sales_price` and `colour`, you can use a filler algorithm like KNN-imputer or just fill the value of prices by mean or median.

# %%
# consider products which have price information, data['formatted_price'].isnull() => gives the information 
# about the dataframe row's which have null values price == None|Null
data = data.loc[~data['sales_price'].isnull()]
#This will store those values whose 'formatted_price' is not null
print('Number of data points After eliminating price = NULL :', data.shape[0])
# Out:
# Number of data points After eliminating price = NULL : 4613

# %% [markdown]
# We'll also drop the null colour rows.

# %%
# consider products which have color information
# data['color'].isnull() => gives the information about the dataframe row's which have null values price == None|Null
data =data.loc[~data['colour'].isnull()]
print('Number of data points After eliminating colour = NULL :', data.shape[0])
# Out:
# Number of data points After eliminating colour = NULL : 4613

# %% [raw]
# We'll also drop the null brand rows.

# %%
# consider products which have color information
# data['color'].isnull() => gives the information about the dataframe row's which have null values price == None|Null
data =data.loc[~data['colour'].isnull()]
print('Number of data points After eliminating colour = NULL :', data.shape[0])
# Out:
# Number of data points After eliminating colour = NULL : 4613

# %%
# find number of products that have duplicate titles.
print(sum(data.duplicated('product_name')))
# Out:
# 515

# %% [markdown]
# We have 515 products which have same title but different color.

# %% [markdown]
# Now as a part of feature engineering, we'll remove the product_name with short description.

# %%
# Remove All products with very few words in title
data_sorted = data[data['product_name'].apply(lambda x: len(x.split())>4)]
print("After removal of products with short description:", data_sorted.shape[0])
# Out:
# After removal of products with short description: 4261

# %% [markdown]
# We'll alphabetically sort the data and replace sorted description with titles.

# %%
# Sort the whole data based on title (alphabetical order of title) 
data_sorted.sort_values('product_name',inplace=True, ascending=False)
data_sorted.head()
# Out:
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\2903781420.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sorted.sort_values('product_name',inplace=True, ascending=False)
#              asin          brand  \
# 23432  B07PM5FZ5Y        Yashika
# 6543   B084D7FYMC  weaver's tale
# 7785   B00HR5BPKU         uxcell
# 10224  B07PRVK49D           uniq
# 9717   B07PRVK49D           uniq
#
#                                                   colour  \
# 23432                                         Blue|Green
# 6543   black|firozi blue|gold|gold, pink|green, blue|...
# 7785                          Black-White|Gray|Navy Blue
# 10224                   Red|black|rcb|rcb black|rcb eros
# 9717                    Red|black|rcb|rcb black|rcb eros
#
#                                        image_urls__small  \
# 23432  https://images-na.ssl-images-amazon.com/images...
# 6543   https://images-na.ssl-images-amazon.com/images...
# 7785   https://images-na.ssl-images-amazon.com/images...
# 10224  https://images-na.ssl-images-amazon.com/images...
# 9717   https://images-na.ssl-images-amazon.com/images...
#
#                                             product_name  rating  sales_price
# 23432  women's art silk kalamkari and bhagalpuri styl...     5.0        299.0
# 6543   weaver's tale women's handloom woven organza b...     2.4       2100.0
# 7785   uxcell Women Winter Stripes Heart Print Finger...     4.8       1039.0
# 10224                           uniq rcb Jersey 2019 ipl     3.3        259.0
# 9717                            uniq rcb Jersey 2019 ipl     3.3        259.0

# %% [markdown]
# [WarningError](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy)

# %% [markdown]
# ## **4. Removing Most Similar Duplicates**

# %% [markdown]
# We'll store the indices in an empty list.

# %%
indices = []               
for i, row in data_sorted.iterrows():  # Iterate over DataFrame rows as (index, Series) pairs.
    indices.append(i)

# %% [markdown]
# Our main Logic code, this code removes duplicates which vary at the ends.

# %%
import itertools

# We'll remove the duplicates which differ only at the end.
duplicates = []  
# 2 variables used at iterators.
i = 0
j = 0
num_data_points = data_sorted.shape[0]   # Number of data points in our dataframe.

while i < num_data_points and j < num_data_points:
    
    previous_i = i

    # store the list of words of ith string in a, ex: a = ['tokidoki', 'The', 'Queen', 'of', 'Diamonds', 'Women's', 'Shirt', 'X-Large']
    a = data['product_name'].loc[indices[i]].split()

    # search for the similar products sequentially as they are arranged alphabetically. 
    j = i+1
    while j < num_data_points:

        # store the list of words of jth string in b, ex: b = ['tokidoki', 'The', 'Queen', 'of', 'Diamonds', 'Women's', 'Shirt', 'Small']
        b = data['product_name'].loc[indices[j]].split()

        # store the maximum length of two strings.
        length = max(len(a), len(b))

        # count is used to store the number of words that are matched in both strings.
        count  = 0

        # itertools.zip_longest(a,b): will map the corresponding words in both strings, it will appened None in case of unequal strings
        # example: a =['a', 'b', 'c', 'd']
        # b = ['a', 'b', 'd']
        # itertools.zip_longest(a,b): will give [('a','a'), ('b','b'), ('c','d'), ('d', None)]
        for k in itertools.zip_longest(a, b): 
            if (k[0] == k[1]):          # Checking if the pair made is same or not.
                count += 1              # If one pair is same, we'll increase the count by 1.

        # if the number of words in which both strings differ are > 2 , we are considering it as those two apperals are different.
        # if the number of words in which both strings differ are < 2 , we are considering it as those two apperals are same, hence we are ignoring them.
        if (length - count) > 2: # number of words in which both sentences differ.
            # if both strings are differ by more than 2 words we include the 1st string index.
            duplicates.append(data_sorted['asin'].loc[indices[i]])

            # if the comparision between is between num_data_points, num_data_points-1 strings and they differ in more than 2 words we include both.
            if j == num_data_points-1: duplicates.append(data_sorted['asin'].loc[indices[j]])

            # start searching for similar apperals corresponds 2nd string.
            i = j
            break
        else:
            j += 1
    if previous_i == i:
        break

# %%
# We'll take only those 'asins' which have not similar titles(After removing titles that differ only in last few words).
data = data.loc[data['asin'].isin(duplicates)]   # Whether each element in the DataFrame is contained in values.

# %% [markdown]
# We removed the dupliactes which differ only at the end.

# %% [markdown]
# Total Number of datapoints we are gonna deal with.

# %%
print('Number of data points at final stage:', data.shape[0])
# Out:
# Number of data points at final stage: 3692

# %% [markdown]
# ## **5. Text pre-processing**

# %% [markdown]
# We'll use NLTK Library for removing stopwords which don't provide us any information relating the product_name.

# %%
import nltk 
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Abhishek
# [nltk_data]     Sharma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Next, I'll write a helper fuction which will preprocess our text for model training.

# %%
# we use the list of stop words that are downloaded from nltk lib.
stop_words = set(stopwords.words('english'))
# print('list of stop words:', stop_words)

def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        for words in total_text.split():
            # remove the special chars in review like '"#$@!%^&*()_+-~?>< etc.
            word = ("".join(e for e in words if e.isalnum())) # Returns only words with (A-z) and (0-9)
            # Conver all letters to lower-case
            word = word.lower()
            # stop-word removal
            if not word in stop_words:
                string += word + " "
        data[column][index] = string

# %% [markdown]
# Applying the function to our dataframe.

# %%
# we take each title and we text-preprocess it.
for index, row in data.iterrows():
    nlp_preprocessing(row['product_name'], index, 'product_name')
# Out:
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data[column][index] = string
# C:\Users\Abhishek Sharma\AppData\Local\Temp\ipykernel_23168\299712002.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column][index] = string
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Let's see our final dataframe.

# %%
data.head()
# Out:
#           asin             brand  \
# 5   B07X5M41BJ       Forest Club
# 6   B07H9RCVHQ      PrintOctopus
# 15  B083ZKXVGN        Miss Chase
# 20  B07K6PHHHM             PuJoy
# 22  B0759HPKCJ  kalpit creations
#
#                                                colour  \
# 5                                     Black|Blue|Grey
# 6                                     Black|Navy Blue
# 15                                       Black|Maroon
# 20  Black Based|Black Based 2|Black White|Blue Whi...
# 22  Black|Bottle green|GREEN|NAVY BLUE|Pink|Red|WH...
#
#                                     image_urls__small  \
# 5   https://images-na.ssl-images-amazon.com/images...
# 6   https://images-na.ssl-images-amazon.com/images...
# 15  https://images-na.ssl-images-amazon.com/images...
# 20  https://images-na.ssl-images-amazon.com/images...
# 22  https://images-na.ssl-images-amazon.com/images...
#
#                                          product_name  rating  sales_price
# 5   forest club  gym wear  sports shorts shorts me...     4.1        350.0
# 6   printoctopus graphic printed tshirt men chill ...     3.7        288.0
# 15  miss chase womens solid shoulder cutout halfsl...     3.7        669.0
# 20  pujoy womens soft cotton traditional bengali h...     3.5        420.0
# 22  kalpit creations mens comfort soft cotton blac...     3.2        249.0

# %% [markdown]
# ## 6. Stemming

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()

# %% [markdown]
# ## 7. Important Utility Functions

# %% [markdown]
# Let's setup the imports required for the functions to run.

# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
from matplotlib import gridspec
from sklearn.metrics import pairwise_distances
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import math
import seaborn as sns

# %% [markdown]
# ### 7.1 Display an image
#
# Our first helper function will display the image for visuals using requests.

# %%
def display_img(url, ax, fig):
    # we get the url of the apparel and download it
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    # we will display it in notebook 
    plt.imshow(img)

# %% [markdown]
# ### 7.2 Plotting code
#
# Helps us to understand and visualize the algorithm's decision.

# %%
def plot_heatmap(keys, values, labels, url, text):
        # keys: list of words of recommended title
        # values: len(values) ==  len(keys), values(i) represents the occurence of the word keys(i)
        # labels: len(labels) == len(keys), the values of labels depends on the model we are using
                # if model == 'bag of words': labels(i) = values(i)
                # if model == 'tfidf weighted bag of words':labels(i) = tfidf(keys(i))
                # if model == 'idf weighted bag of words':labels(i) = idf(keys(i))
        # url : apparel's url

        # we will devide the whole figure into two parts
        gs = gridspec.GridSpec(2, 2, width_ratios=[4,1], height_ratios=[4,1]) 
        fig = plt.figure(figsize=(25,3))
        
        # 1st, ploting heat map that represents the count of commonly ocurred words in title2
        ax = plt.subplot(gs[0])
        # it displays a cell in white color if the word is intersection(lis of words of title1 and list of words of title2), in black if not
        ax = sns.heatmap(np.array([values]), annot=np.array([labels]))
        ax.set_xticklabels(keys) # set that axis labels as the words of title
        ax.set_title(text) # apparel title
        
        # 2nd, plotting image of the the apparel
        ax = plt.subplot(gs[1])
        # we don't want any grid lines for image and no labels on x-axis and y-axis
        ax.grid(False)
        ax.set_xticks([])
        ax.set_yticks([])
        
        # we call dispaly_img based with paramete url
        display_img(url, ax, fig)
        
        # displays combine figure ( heat map and image together)
        plt.show()

# %% [markdown]
# ### 7.3 Plot Heatmap with Apparel Image
#
# This function will plot a heatmap with the apparel image.

# %%
def plot_heatmap_image(doc_id, vec1, vec2, url, text, model):

    # doc_id : index of the title1
    # vec1 : input apparels's vector, it is of a dict type {word:count}
    # vec2 : recommended apparels's vector, it is of a dict type {word:count}
    # url : apparels image url
    # text: title of recomonded apparel (used to keep title of image)
    # model, it can be any of the models, 
        # 1. bag_of_words
        # 2. tfidf
        # 3. idf

    # we find the common words in both titles, because these only words contribute to the distance between two title vec's
    intersection = set(vec1.keys()) & set(vec2.keys()) 

    # we set the values of non intersecting words to zero, this is just to show the difference in heatmap
    for i in vec2:
        if i not in intersection:
            vec2[i]=0

    # for labeling heatmap, keys contains list of all words in title2
    keys = list(vec2.keys())
    # if ith word in intersection(lis of words of title1 and list of words of title2): values(i)=count of that word in title2 else values(i)=0 
    values = [vec2[x] for x in vec2.keys()]
    
    # labels: len(labels) == len(keys), the values of labels depends on the model we are using
        # if model == 'bag of words': labels(i) = values(i)
        # if model == 'tfidf weighted bag of words':labels(i) = tfidf(keys(i))
        # if model == 'idf weighted bag of words':labels(i) = idf(keys(i))

    if model == 'bag_of_words':
        labels = values
    elif model == 'tfidf':
        labels = []
        for x in vec2.keys():
            # tfidf_title_vectorizer.vocabulary_ it contains all the words in the corpus
            # tfidf_title_features[doc_id, index_of_word_in_corpus] will give the tfidf value of word in given document (doc_id)
            if x in  tfidf_title_vectorizer.vocabulary_:
                labels.append(tfidf_title_features[doc_id, tfidf_title_vectorizer.vocabulary_[x]])
            else:
                labels.append(0)

    plot_heatmap(keys, values, labels, url, text)

# %% [markdown]
# ### 7.4 Text to Vector
#
# This function converts the text to a vector.

# %%
# this function gets a list of words along with the frequency of each 
# word given "text"
def text_to_vector(text):
    word = re.compile(r'\w+')
    words = word.findall(text)
    # words stores list of all words in given string, you can try 'words = text.split()' this will also gives same result
    return Counter(words) # Counter counts the occurence of each word in list, it returns dict type object {word1:count}

# %% [markdown]
# ### 7.5 Result Function
#
# Our final function will display the output for a method (BOW or TF-IDF).

# %%
def get_result(doc_id, content_a, content_b, url, model):
    text1 = content_a
    text2 = content_b
    
    # vector1 = dict{word11:#count, word12:#count, etc.}
    vector1 = text_to_vector(text1)

    # vector1 = dict{word21:#count, word22:#count, etc.}
    vector2 = text_to_vector(text2)

    plot_heatmap_image(doc_id, vector1, vector2, url, text2, model)

# %% [markdown]
# Our code-flow for a particular method (BOW or TF-IDF) will go as follows:
#
# ` get_result --> text_to_vector --> plot_heatmap_image --> plot_heatmap --> display_image`

# %% [markdown]
# ## **8. Bag Of Words based Product Similarity**

# %% [markdown]
# Let's import the Bag of Words method from sklearn and store the BOW feature matrix.

# %%
from sklearn.feature_extraction.text import CountVectorizer
bow_title_vectorizer = CountVectorizer()
bow_title_features = CountVectorizer().fit_transform(data['product_name'])
bow_title_features.get_shape()
# Out:
# (3692, 5417)

# %% [markdown]
# Our helper function will recommend us similar apparels using a `doc_id` which is similar to a `query`. We'll use pairwise distance to compare similarites between clusters (bow feature matrix).

# %%
def bag_of_words_model(doc_id, num_results):
    # doc_id: apparel's id in given corpus
    
    # pairwise_dist will store the distance from given input apparel to all remaining apparels
    # the metric we used here is cosine, the cosine distance is mesured as K(X, Y) = <X, Y> / (||X||*||Y||)
    # http://scikit-learn.org/stable/modules/metrics.html#cosine-similarity
    pairwise_dist = pairwise_distances(bow_title_features, bow_title_features[doc_id], metric='cosine', n_jobs=-1)
    
    # np.argsort will return `num_results` indices of the smallest distances
    indices = np.argsort(pairwise_dist.flatten())[0:num_results]
    #pdists will store the smallest distances
    pdists  = np.sort(pairwise_dist.flatten())[0:num_results]
    # np.argsort returns the indices of the smallest distances in ascending order.
    # The sort() method sorts the list ascending by default.

    #data frame indices of the 9 smallest distace's
    df_indices = list(data.index[indices])
    
    #displaying the results.
    for i in range(0, len(indices)):
        # we will pass 1. doc_id, 2. title1, 3. title2, 4. url, 5. model
        get_result(indices[i], data['product_name'].loc[df_indices[0]], 
                   data['product_name'].loc[df_indices[i]], 
                   data['image_urls__small'].loc[df_indices[i]], 'bag_of_words')
        
        print('ASIN :',data['asin'].loc[df_indices[i]])
        print ('Brand:', data['brand'].loc[df_indices[i]])
        print ('Title:', data['product_name'].loc[df_indices[i]])
        print ('Euclidean similarity with the query image :', pdists[i])
        print('='*80)

# %% [markdown]
# Now, let's call the bag of words model and see the results.

# %%
#call the bag-of-words model for a product to get similar products.
bag_of_words_model(12, 20) # change the index if you want to.
# In the output heat map each value represents the count value 
# of the label word, the color represents the intersection 
# with inputs title.
# 12 is the index of the "Query title"
#try 931
# Out:
# ASIN : B083Q45SS7
# Brand: Jevi Prints
# Title: Jevi Prints Women's Cotton Printed Straight Kurta (PRJ-617)
# Euclidean similarity with the query image : 1.1102230246251565e-16
# ================================================================================
# ASIN : B07KYTLNZC
# Brand: nan
# Title: Pepe Jeans Girl's Plain Regular fit T-Shirt
# Euclidean similarity with the query image : 0.5669872981077806
# ================================================================================
# ASIN : B07RMT7VS3
# Brand: nan
# Title: Hopcara® Unisex Kids Cotton Printed Regular Fit T-Shirt Combo (Set of 2) (Mommy's Little Man, Black, Blue)
# Euclidean similarity with the query image : 0.5735985672887791
# ================================================================================
# ASIN : B01NASG9DY
# Brand: nan
# Title: Cherokee by Unlimited Girls' T-Shirt
# Euclidean similarity with the query image : 0.5991081371313635
# ================================================================================
# ASIN : B071NM9X7N
# Brand: nan
# Title: Vishudh Women's Straight Kurta
# Euclidean similarity with the query image : 0.5991081371313635
# ================================================================================
# ASIN : B07NSXN5DT
# Brand: TEXCO
# Title: TEXCO Off Shoulder Women Crop Top
# Euclidean similarity with the query image : 0.6250000000000001
# ================================================================================
# ASIN : B07MNDPRSB
# Brand: Fully
# Title: Fully New Stylish Winter Gloves For Men And Boys, Pack Of 1
# Euclidean similarity with the query image : 0.6250000000000001
# ================================================================================
# ASIN : B01DZVKX5C
# Brand: GRITSTONES
# Title: GRITSTONES Men's Button Front Cotton T-Shirt
# Euclidean similarity with the query image : 0.6250000000000001
# ================================================================================
# ASIN : B07M7JDDC9
# Brand: nan
# Title: CHKOKKO Sports, Gym, Running Racer Back Non Wired Padded Sports Bra for Women
# Euclidean similarity with the query image : 0.6250000000000001
# ================================================================================
# ASIN : B07F9L9Y8K
# Brand: BIBA
# Title: BIBA Women's Straight Kurta
# Euclidean similarity with the query image : 0.6250000000000001
# ================================================================================
# ASIN : B07PNXS9YD
# Brand: Ritu-Creation
# Title: Ritu-Creation Women’s Cotton Spandex Air Bra, Sports Bra, Stretchable Padded Seamless Bra with Removable Soft Cups, Free Size, Pack of 2,White/Beige
# Euclidean similarity with the query image : 0.6464466094067263
# ================================================================================
# ASIN : B01NAVDBER
# Brand: MODS
# Title: The Mods cotton white Blue stripe Shirt
# Euclidean similarity with the query image : 0.6464466094067263
# ================================================================================
# ASIN : B019QF3JJI
# Brand: nan
# Title: Flying Machine Men's T-Shirt
# Euclidean similarity with the query image : 0.6645898033750315
# ================================================================================
# ASIN : B0727S3TBC
# Brand: Hot Leathers
# Title: Black White Skull Paisley Head Wrap Durag Skull Cap Biker Bandanna Doo Rag
# Euclidean similarity with the query image : 0.6645898033750315
# ================================================================================
# ASIN : B07S3XXXTQ
# Brand: Fajabee
# Title: Fajabee Women's Straight Light Blue Embroidered Kurti
# Euclidean similarity with the query image : 0.6645898033750315
# ================================================================================
# ASIN : B07HXWVDKK
# Brand: RIRO
# Title: RIRO Cotton Kids/Boys Velcro dhoti/velcro mundu/Double dhoti/Jari Cotton dhoti/Zari cotton dhoti/branded Jari cotton hip closure Double Dhoties(Pack Of 2)_Multi color
# Euclidean similarity with the query image : 0.6645898033750315
# ================================================================================
# ASIN : B07HF6TP7B
# Brand: CASROD
# Title: CASROD Men's Round Neck Half Sleeve Graphic Print T Shirt York Basketball
# Euclidean similarity with the query image : 0.6645898033750315
# ================================================================================
# ASIN : B01EWZ9WVQ
# Brand: PRAKASAM COTTON
# Title: PRAKASAM COTTON Men's Cotton Dhoti
# Euclidean similarity with the query image : 0.6801989254665843
# ================================================================================
# ASIN : B081ZHLNWW
# Brand: Tinted
# Title: Tinted Men's Solid Slim Fit T-Shirt
# Euclidean similarity with the query image : 0.6801989254665843
# ================================================================================
# ASIN : B07MNSSX2G
# Brand: nan
# Title: United Colors of Benetton Men's Printed Regular fit T-Shirt
# Euclidean similarity with the query image : 0.6801989254665843
# ================================================================================

# %% [markdown]
# This execution shows us the 20 most similar products related to the apparel at *Id = 12* (BOW model). This is similar to query in retrieval systems. For example, when you type a query to search for some product on Amazon, the search engine will map your query against a set of keys (featues and feature matrix) associated with candidate products in the database, then present you the best matched videos (values/pdsit in this notebook).

# %% [markdown]
# ## **9. Summary**

# %% [markdown]
# As you can see the system is quite accurately giving us the product recommendation. I think the BOW model is giving us quite a good variety of products and also displaying different types of brands. In tfidf model, the products are quite restricted to being similar and of the same brand but BOW is giving us a better variety since it is changing the brands.
#
#
# In this notebook we learned,
# - Basic data statistics.
# - How to build an easy recommendation system using BOW and TF-IDF.
# - Visualized the results with heatmaps and images from json files.
# - Used cosine similarity and pariwise distances as metrics to evaluate product similarity.
#
# Due to time constraints and an easy to use application, I used only around 17k data points, if you have time to spare you can get even better results by not dropping the null values. On the other hand, removing duplicates was quite important as in the last fewer words the only thing irrelavant was the size of the apparel, it is pretty obvious the customer doesn't want to see the exact same product with only a change in the size, hence removing it was a must.
#
# Finally, you can also try using weighted word2vec models from gensim to make a new feature matrix which will pay attention to the important part in the titles.
